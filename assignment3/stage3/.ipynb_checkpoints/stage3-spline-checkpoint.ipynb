# %%
import math
import pandas as pd
import numpy as np
import scipy
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy import stats
from datetime import datetime
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
from sklearn.metrics import mean_squared_error
from math import sqrt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-61-7d0561367b84> in <module>
#       3 import numpy as np
#       4 import scipy
# ----> 5 from statsmodels.regression.linear_model import GLM
#       6 import matplotlib.pyplot as plt
#       7 from scipy import stats
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/regression/__init__.py in <module>
# ----> 1 from .linear_model import yule_walker
#       2
#       3 from statsmodels import PytestTester
#       4 test = PytestTester()
#       5
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/regression/linear_model.py in <module>
#      46                                           cache_readonly,
#      47                                           cache_writable)
# ---> 48 import statsmodels.base.model as base
# ...

# %% [markdown]
# # Reading data

# %%
traindata_df = pd.read_csv('data/TrainData2.csv', delimiter = ',').dropna().reset_index(drop=True)
traindata_df['TIMESTAMP'] = pd.to_datetime(traindata_df['TIMESTAMP'], format='%Y%m%d %H:%M')
traindata_df = traindata_df.set_index('TIMESTAMP')
std_dev = 3
traindata_df = traindata_df[(np.abs(stats.zscore(traindata_df)) < float(std_dev)).all(axis=1)]

# %%
forecast_df = pd.read_csv('data/WeatherForecastInput2.csv', delimiter = ',')
forecast_df['TIMESTAMP'] = pd.to_datetime(forecast_df['TIMESTAMP'], format='%Y%m%d %H:%M')
forecast_df = forecast_df.set_index('TIMESTAMP')

# %%
results_st2 = pd.read_csv('data/Solution2.csv', delimiter = ',')
results_st2['TIMESTAMP'] = pd.to_datetime(results_st2['TIMESTAMP'], format='%Y%m%d %H:%M')
results_st2 = results_st2.set_index('TIMESTAMP')

# %% [markdown]
# # Feature Engineering

# %%
X = pd.DataFrame()
#X['U10'] = train_df['U10']
#X['U100'] = train_df['U100']
#X['V10'] = train_df['V10']
#X['V100'] = train_df['V100']
#X['U10^2'] = X['U10']**2
#X['U100^2'] = X['U100']**2
#X['V10^2'] = X['V10']**2
#X['V100^2'] = X['V100']**2
#X['U10^3'] = X['U10']**3
#X['U100^3'] = X['U100']**3
#X['V10^3'] = X['V10']**3
#X['V100^3'] = X['V100']**3

X['W10'] = (np.sqrt(traindata_df['U10']**2 + traindata_df['V10']**2))
#X['W100'] = (np.sqrt(train_df['U100']**2 + train_df['V100']**2))**3
#X['W10^2'] = X['W10']**2
#X['W100^2'] = X['W100']**2
#X['W10^3'] = X['W10']**3
#X['W100^3'] = X['W100']**3
#X['cosTheta10'] = train_df['U10']/X['W10']
#X['sinTheta10'] = train_df['V10']/X['W10']
#X['cosTheta100'] = train_df['U100']/X['W100']
#X['sinTheta100'] = train_df['V100']/X['W100']

#X['beta_0'] = 1

#X['hour'] = X.index.hour
#X['year'] = X.index.year
#X['month'] = X.index.month

y = traindata_df[['POWER']].copy()

X_pred = pd.DataFrame()

#X_pred['U10'] = pred_df['U10']
#X_pred['U100'] = pred_df['U100']
#X_pred['V10'] = pred_df['V10']
#X_pred['V100'] = pred_df['V100']
#X_pred['U10^2'] = X_pred['U10']**2
#X_pred['U100^2'] = X_pred['U100']**2
#X_pred['V10^2'] = X_pred['V10']**2
#X_pred['V100^2'] = X_pred['V100']**2
#X_pred['U10^3'] = X_pred['U10']**3
#X_pred['U100^3'] = X_pred['U100']**3
#X_pred['V10^3'] = X_pred['V10']**3
#X_pred['V100^3'] = X_pred['V100']**3

X_pred['W10'] = (np.sqrt(forecast_df['U10']**2 + forecast_df['V10']**2))
#X_pred['W100'] = (np.sqrt(pred_df['U100']**2 + pred_df['V100']**2))**3
#X_pred['W10^2'] = X_pred['W10']**2
#X_pred['W100^2'] = X_pred['W100']**2
#X_pred['W10^3'] = X_pred['W10']**3
#X_pred['W100^3'] = X_pred['W100']**3
#X_pred['cosTheta10'] = pred_df['U10']/X_pred['W10']
#X_pred['sinTheta10'] = pred_df['V10']/X_pred['W10']
#X_pred['cosTheta100'] = pred_df['U100']/X_pred['W100']
#X_pred['sinTheta100'] = pred_df['V100']/X_pred['W100']

#X_pred['beta_0'] = 1

#X_pred['hour'] = X_pred.index.hour
#X_pred['year'] = X_pred.index.year
#X_pred['month'] = X_pred.index.month

# %% [markdown]
# # Third stage

# %%
X = X['W10']
# Dividing data into train and validation datasets
from sklearn.model_selection import train_test_split
train_x, valid_x, train_y, valid_y = train_test_split(X, y, test_size=0.33, random_state = 1)

# Visualize the relationship b/w age and wage
import matplotlib.pyplot as plt
plt.figure(figsize = (15,15))
plt.scatter(train_x, train_y, facecolor='None', edgecolor='b', alpha=0.5)
plt.show()

# %%
# Dividing the data into 4 bins
df_cut, bins = pd.cut(train_x, 4, retbins=True, right=True)
df_cut.value_counts(sort=False)
# Out:
# (0.00701, 4.67]     4946
# (4.67, 9.314]       9278
# (9.314, 13.958]     2843
# (13.958, 18.602]     211
# Name: W10, dtype: int64

# %%
df_steps = pd.concat([train_x, df_cut, train_y], keys=['W10','W10_cuts','POWER'], axis=1)

# Create dummy variables for the wind speed groups
df_steps_dummies = pd.get_dummies(df_cut)
#df_steps_dummies.head()

# %%
df_steps_dummies.columns = ['0.00701-4.67','4.67-9.314','9.314-13.958','13.958-18.602'] 

# Fitting Generalised linear models
fit3 = sm.GLM(df_steps.POWER, df_steps_dummies).fit()

# Binning validation set into same 4 bins
bin_mapping = np.digitize(valid_x, bins) 
X_valid = pd.get_dummies(bin_mapping)

# Removing any outliers
X_valid = pd.get_dummies(bin_mapping).drop([5], axis=1)

# Prediction
pred2 = fit3.predict(results_st2)

# Calculating RMSE
from sklearn.metrics import mean_squared_error 
from math import sqrt 
rms = sqrt(mean_squared_error(valid_y, pred2)) 
print(rms)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-56-28533b4987cb> in <module>
#       2
#       3 # Fitting Generalised linear models
# ----> 4 fit3 = sm.api.GLM(df_steps.POWER, df_steps_dummies).fit()
#       5
#       6 # Binning validation set into same 4 bins
#
# AttributeError: module 'statsmodels' has no attribute 'api'

# %%
# We will plot the graph for 70 observations only
xp = np.linspace(valid_x.min(),valid_x.max()-1,70) 
bin_mapping = np.digitize(xp, bins) 
X_valid_2 = pd.get_dummies(bin_mapping) 
pred2 = fit3.predict(X_valid_2)

# %%
dir(sm)
# Out:
# ['CacheWriteWarning',
#  'ConvergenceWarning',
#  'InvalidTestWarning',
#  'IterationLimitWarning',
#  'LooseVersion',
#  'PytestTester',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  'base',
#  'compat',
#  'datasets',
#  'debug_warnings',
#  'iolib',
#  'os',
#  'print_function',
#  'simplefilter',
#  'stats',
#  'sys',
#  'test',
#  'tools',
#  'version']

# %%
dir(sm.version.version)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
sm.version
# Out:
# <module 'statsmodels.version' from '/Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/statsmodels/version.py'>

# %%
sm.sys.api_version
# Out:
# 1013
